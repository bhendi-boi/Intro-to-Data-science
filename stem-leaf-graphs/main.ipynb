# %% [markdown]
# ## What are stem-leaf graphs

# %% [markdown]
# A stem-and-leaf display or stem-and-leaf plot is a device for presenting quantitative data in a graphical format, similar to a histogram, to assist in visualizing the shape of a distribution.

# %% [markdown]
# ## How to use them ?

# %% [markdown]
# - To construct a stem-and-leaf display, the observations must first be sorted in ascending order.
# - Next, it must be determined what the stems will represent and what the leaves will represent.
# - Typically, the leaf contains the last digit of the number and the stem contains all of the other digits.
# - The remaining digits to the left of the rounded place value are used as the stem.
# - The stem-and-leaf display is drawn with two columns separated by a vertical line.
# - The stems are listed to the left of the vertical line. It is important that each stem is listed only once and that no numbers are skipped, even if it means that some stems have no leaves.
# - The leaves are listed in increasing order in a row to the right of each stem.

# %% [markdown]
# ![A typical Stemgraph](./stemgraph-usecase.png)

# %% [markdown]
# ## How to stemgraph in python

# %% [markdown]
# We make use of the stemgraphic library for this.
# Link to the [docs](http://stemgraphic.org/doc/intro.html)

# %%
from stemgraphic import stem_graphic

# %%
numbers = [2,3,4,6,12,15,19,32,45,47,48]

# %%
stem_graphic(numbers, scale=10)
# Out:
# (<Figure size 750x200 with 1 Axes>, <Axes: >)

# %% [markdown]
# `stem_graphic` displays maximum, minimum values. The value which is underlined is the median of our dataset.
